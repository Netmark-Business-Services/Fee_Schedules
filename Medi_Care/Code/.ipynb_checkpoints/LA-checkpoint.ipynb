# %%
import pandas as pd
import os
# Area 17 - LA county
# Rename the input file to LA MM.DD.YYYY

#read files
file_path = "../Input_Files/LA 03.09.2024.xlsx"
df = pd.read_excel(file_path, skiprows=8)
df.columns = ['Note', 'SVC_CD', 'Modifier_1', 'FEE','Non_Par_Fee', 'Limiting_Charge_Fee']

#Drop the last two columns 
df.drop(['Non_Par_Fee', 'Limiting_Charge_Fee'], axis=1, inplace=True)

#Split the date
date_part = file_path.split(" ")[-1].split(".")  
split_date = '-'.join(date_part[0:3])
month, day, year = split_date.split('-')
if len(year) == 2:
    year = '20' + year
date = f'{year}{month}{day}'
date1=f'{year}-{month}-{day}'
# Create a directory named after the date if it doesn't exist
if not os.path.exists(f'../Output_Files/{year}/{date}'):
    os.makedirs(f'../Output_Files/{year}/{date}')    

#Fill 'Note' Column with ab in place in NaN and add 'ASOFDATE'
df['Note'] = df['Note'].fillna('ab')
df['ASOFDATE'] = date

# Create two new dataframes based on the condition
df_normal = df[df['Note'].str.contains('ab')]
df_op = df[~df['Note'].str.contains('ab')]

#Drop the 'Note' Column
df_normal.drop(['Note'], axis=1, inplace=True)
df_op.drop(['Note'], axis=1, inplace=True)


df_normal.to_csv(f'../Output_Files/{year}/{date}/MCare_LA.{date1}.txt', sep='|', index=False)
df_op.to_csv(f'../Output_Files/{year}/{date}/MCare_LA_OP.{date1}.txt', sep='|', index=False)
   
#final_df_a.shape
print("code executed succesfully")
display(df_op)
display(df_normal)
# Out:
# code executed succesfully
# C:\Users\skrishnan\AppData\Local\Temp\ipykernel_17168\4138864687.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_normal.drop(['Note'], axis=1, inplace=True)
# C:\Users\skrishnan\AppData\Local\Temp\ipykernel_17168\4138864687.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_op.drop(['Note'], axis=1, inplace=True)
#       SVC_CD Modifier_1     FEE  ASOFDATE
# 1      G0011        NaN   23.50  20240309
# 4      G0013        NaN    9.12  20240309
# 6      G0017        NaN  192.52  20240309
# 8      G0018        NaN   96.38  20240309
# 10     G0019        NaN   52.21  20240309
# ...      ...        ...     ...       ...
# 11113  99494        NaN   42.87  20240309
# 11115  99495        NaN  146.10  20240309
# 11117  99496        NaN  198.43  20240309
# 11119  99497        NaN   78.60  20240309
# 11121  99498        NaN   74.00  20240309
#
# [2109 rows x 4 columns]
#       SVC_CD Modifier_1     FEE  ASOFDATE
# 0      G0011        NaN   28.23  20240309
# 2      G0012        NaN   15.87  20240309
# 3      G0013        NaN   26.45  20240309
# 5      G0017        NaN  223.63  20240309
# 7      G0018        NaN  110.55  20240309
# ...      ...        ...     ...       ...
# 11112  99494        NaN   64.92  20240309
# 11114  99495        NaN  226.83  20240309
# 11116  99496        NaN  306.73  20240309
# 11118  99497        NaN   87.26  20240309
# 11120  99498        NaN   74.79  20240309
#
# [9013 rows x 4 columns]
